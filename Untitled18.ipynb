# %% [markdown]
# <a href="https://colab.research.google.com/github/hmdaalln/Group7/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
import cv2
from matplotlib import pyplot as plt
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 128

# %%
transform = transforms.Compose(
    [transforms.ToTensor()])

# %%
# if you already have: import torchvision.transforms as T
# and defined train_tfms / test_tfms and BATCH_SIZE

trainset = torchvision.datasets.CIFAR100(root='./cifar_100', train=True,
                                         download=True, transform=train_tfms)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE,
                                           shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./cifar_100', train=False,
                                        download=True, transform=test_tfms)
test_loader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE,
                                          shuffle=False, num_workers=2)

classes = trainset.classes  # official CIFAR-100 class names


classes = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup',
    'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house',
    'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man',
    'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid',
    'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew',
    'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower',
    'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train',
    'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

# %%
import torch
import torch.nn as nn
from torchvision import models

class ResNet18CustomInput(nn.Module):
    def __init__(self, num_classes=100, input_channels=3):
        super(ResNet18CustomInput, self).__init__()

        # Load pre-trained ResNet-18
        self.resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

        # Modify first conv layer for CIFAR input
        self.resnet.conv1 = nn.Conv2d(input_channels, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.resnet.maxpool = nn.Identity()  # remove large 7x7 downsampling

        # Replace FC layer for CIFAR-100
        in_features = self.resnet.fc.in_features  # 512 for ResNet-18
        self.resnet.fc = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.resnet(x)

# Instantiate and move to GPU
num_classes = 100
input_channels = 3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = ResNet18CustomInput(num_classes, input_channels).to(device)
print("✅ ResNet-18 for CIFAR-100 ready on", device)
# Out:
# ✅ ResNet-18 for CIFAR-100 ready on cuda

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
def train(model, train_loader, optimizer, criterion, epoch):
    model.train()
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch,
                batch_idx * len(inputs),
                len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.item()
            ))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0.0
    correct = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            output = model(inputs)
            loss = criterion(output, labels)
            test_loss += loss.item() * inputs.size(0)  # multiply by batch size
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(labels.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), accuracy))

    return test_loss, accuracy

# %%
epochs = 50
for epoch in range(1, epochs + 1):
    train(model, train_loader, optimizer, criterion, epoch)
    test(model, test_loader)
    torch.save(model.state_dict(), 'cifar100_resnet18_model.pth')
    print('model saved')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 4.856494
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 2.581476
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.892873
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.618110
#
# Test set: Average loss: 1.4490, Accuracy: 5842/10000 (58.42%)
#
# model saved
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.341923
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.279057
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.229087
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.929038
#
# Test set: Average loss: 1.2004, Accuracy: 6517/10000 (65.17%)
#
# model saved
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.804344
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.966229
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.100703
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.040757
#
# Test set: Average loss: 1.0610, Accuracy: 6939/10000 (69.39%)
#
# model saved
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.661831
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.689446
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.935313
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.861167
#
# Test set: Average loss: 0.9930, Accuracy: 7089/10000 (70.89%)
#
# model saved
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.766557
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.588262
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.725003
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.715126
#
# Test set: Average loss: 0.9754, Accuracy: 7239/10000 (72.39%)
#
# model saved
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.643895
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.528928
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.488620
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.616919
#
# Test set: Average loss: 0.9699, Accuracy: 7281/10000 (72.81%)
#
# model saved
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.414738
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.469645
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.354331
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.489200
#
# Test set: Average loss: 0.9533, Accuracy: 7363/10000 (73.63%)
#
# model saved
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.335083
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.382166
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.431771
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.368946
#
# Test set: Average loss: 0.9648, Accuracy: 7304/10000 (73.04%)
#
# model saved
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.274112
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.310577
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.274529
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.372930
#
# Test set: Average loss: 1.0055, Accuracy: 7358/10000 (73.58%)
#
# model saved
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.290512
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.240521
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.269258
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.315122
#
# Test set: Average loss: 0.9938, Accuracy: 7326/10000 (73.26%)
#
# model saved
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.320337
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.354774
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.248792
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.307476
#
# Test set: Average loss: 0.9710, Accuracy: 7457/10000 (74.57%)
#
# model saved
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.272367
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.203414
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.275763
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.282859
#
# Test set: Average loss: 1.0017, Accuracy: 7412/10000 (74.12%)
#
# model saved
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.195365
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.227588
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.256113
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.221493
#
# Test set: Average loss: 0.9536, Accuracy: 7519/10000 (75.19%)
#
# model saved
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.159843
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.215114
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.252389
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.324291
#
# Test set: Average loss: 1.0024, Accuracy: 7456/10000 (74.56%)
#
# model saved
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.207900
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.107845
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.208308
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.220302
#
# Test set: Average loss: 1.0235, Accuracy: 7451/10000 (74.51%)
#
# model saved
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.198980
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.187708
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.205896
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.184220
#
# Test set: Average loss: 1.0130, Accuracy: 7478/10000 (74.78%)
#
# model saved
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.178473
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.133921
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.178436
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.178585
#
# Test set: Average loss: 0.9757, Accuracy: 7565/10000 (75.65%)
#
# model saved
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.117640
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.172228
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.148188
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.110976
#
# Test set: Average loss: 0.9847, Accuracy: 7547/10000 (75.47%)
#
# model saved
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.181408
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.094233
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.158641
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.168168
#
# Test set: Average loss: 1.0199, Accuracy: 7495/10000 (74.95%)
#
# model saved
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.165198
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.081729
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.140795
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.188701
#
# Test set: Average loss: 0.9971, Accuracy: 7593/10000 (75.93%)
#
# model saved
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.073677
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.105985
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.105392
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.180044
#
# Test set: Average loss: 0.9835, Accuracy: 7548/10000 (75.48%)
#
# model saved
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.119952
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.162074
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.182335
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.139700
#
# Test set: Average loss: 1.0176, Accuracy: 7534/10000 (75.34%)
#
# model saved
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.107678
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.123718
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.095911
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.110087
#
# Test set: Average loss: 1.0201, Accuracy: 7533/10000 (75.33%)
#
# model saved
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.127164
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.133292
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.070803
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.159850
#
# Test set: Average loss: 1.0522, Accuracy: 7442/10000 (74.42%)
#
# model saved
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.080381
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.079682
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.100930
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.092313
#
# Test set: Average loss: 1.0245, Accuracy: 7532/10000 (75.32%)
#
# model saved
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.090513
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.126765
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.122635
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.152797
#
# Test set: Average loss: 1.0342, Accuracy: 7486/10000 (74.86%)
#
# model saved
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.087249
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.147477
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.085194
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.137283
#
# Test set: Average loss: 1.0433, Accuracy: 7541/10000 (75.41%)
#
# model saved
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.112546
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.106404
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.112390
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.093111
#
# Test set: Average loss: 1.0291, Accuracy: 7502/10000 (75.02%)
#
# model saved
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.095253
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.120753
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.188510
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.140776
#
# Test set: Average loss: 1.0393, Accuracy: 7530/10000 (75.30%)
#
# model saved
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.218703
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.123270
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.147240
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.150171
#
# Test set: Average loss: 0.9878, Accuracy: 7570/10000 (75.70%)
#
# model saved
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.172248
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.134455
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.116092
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.244519
#
# Test set: Average loss: 1.0092, Accuracy: 7561/10000 (75.61%)
#
# model saved
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.128268
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.112814
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.088538
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.084140
#
# Test set: Average loss: 1.0323, Accuracy: 7510/10000 (75.10%)
#
# model saved
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.122410
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.155175
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.127916
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.099090
#
# Test set: Average loss: 1.0928, Accuracy: 7411/10000 (74.11%)
#
# model saved
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.121242
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.138638
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.175022
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.062929
#
# Test set: Average loss: 1.0189, Accuracy: 7571/10000 (75.71%)
#
# model saved
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.096986
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.093470
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.081082
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.134386
#
# Test set: Average loss: 1.0041, Accuracy: 7554/10000 (75.54%)
#
# model saved
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.100474
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.048422
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.121462
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.133253
#
# Test set: Average loss: 1.0678, Accuracy: 7462/10000 (74.62%)
#
# model saved
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.135334
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.103625
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.107501
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.111016
#
# Test set: Average loss: 1.0429, Accuracy: 7452/10000 (74.52%)
#
# model saved
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.087278
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.076209
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.081897
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.056868
#
# Test set: Average loss: 1.0659, Accuracy: 7456/10000 (74.56%)
#
# model saved
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.111707
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.060996
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.108314
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.102442
#
# Test set: Average loss: 1.0825, Accuracy: 7475/10000 (74.75%)
#
# model saved
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.083410
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.061739
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.102658
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.152919
#
# Test set: Average loss: 1.0531, Accuracy: 7469/10000 (74.69%)
#
# model saved
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.094252
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.135527
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.098365
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.127707
#
# Test set: Average loss: 1.0137, Accuracy: 7483/10000 (74.83%)
#
# model saved
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.199294
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.086652
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.068208
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.068097
#
# Test set: Average loss: 1.1297, Accuracy: 7410/10000 (74.10%)
#
# model saved
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.138021
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.111026
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.150467
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.145252
#
# Test set: Average loss: 1.0749, Accuracy: 7378/10000 (73.78%)
#
# model saved
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.135246
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.139836
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.189979
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.140977
#
# Test set: Average loss: 1.0586, Accuracy: 7441/10000 (74.41%)
#
# model saved
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.099761
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.126955
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.258957
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.132780
#
# Test set: Average loss: 1.0727, Accuracy: 7408/10000 (74.08%)
#
# model saved
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.102534
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.088446
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.075868
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.104123
#
# Test set: Average loss: 1.0842, Accuracy: 7432/10000 (74.32%)
#
# model saved
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.127182
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.086630
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.103514
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.153570
#
# Test set: Average loss: 1.0535, Accuracy: 7468/10000 (74.68%)
#
# model saved
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.101628
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.077358
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.108386
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.073322
#
# Test set: Average loss: 1.0716, Accuracy: 7418/10000 (74.18%)
#
# model saved
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.129641
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.065267
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.103981
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.086945
#
# Test set: Average loss: 1.0640, Accuracy: 7375/10000 (73.75%)
#
# model saved
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.174875
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.116887
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.090114
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.127128
#
# Test set: Average loss: 1.0888, Accuracy: 7436/10000 (74.36%)
#
# model saved

# %%
# -------- Run and print results for all dataset setups --------
EPOCHS = 50
results = {}

setups = {
    "10x10":   (loader_10x10,  tst_10, 10),
    "10x200":  (loader_10x200, tst_10, 10),
    "100x10":  (loader_100x10, testloader, 100),
    "100x200": (loader_100x200, testloader, 100)
}

for name, (train_loader, test_loader, ncls) in setups.items():
    print("\n" + "="*55)
    print(f"--- Training ResNet-18 on {name} ({ncls} classes) ---")
    print("="*55)

    model = ResNet18CustomInput(num_classes=ncls).to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    best_acc = 0.0

    for epoch in range(1, EPOCHS + 1):
        train(model, train_loader, optimizer, criterion, epoch)
        test_loss, test_acc = test(model, test_loader)
        if test_acc > best_acc:
            best_acc = test_acc
            torch.save(model.state_dict(), f"resnet18_{name}.pth")
            print(f"✅ New best model saved for {name} ({best_acc:.2f}%)")

    results[name] = best_acc
    print(f"\n🎯 Final best accuracy for {name}: {best_acc:.2f}%")

print("\n" + "="*60)
print("SUMMARY OF RESULTS")
print("="*60)
for name, acc in results.items():
    print(f"{name:>10s} : {acc:6.2f}%")
# Out:
# =======================================================
# --- Training ResNet-18 on 10x10 (10 classes) ---
# =======================================================
# Train Epoch: 1 [0/100 (0%)]	Loss: 2.606012
#
# Test set: Average loss: 2.3744, Accuracy: 109/1000 (10.90%)
#
# ✅ New best model saved for 10x10 (10.90%)
# Train Epoch: 2 [0/100 (0%)]	Loss: 2.343745
#
# Test set: Average loss: 2.3463, Accuracy: 120/1000 (12.00%)
#
# ✅ New best model saved for 10x10 (12.00%)
# Train Epoch: 3 [0/100 (0%)]	Loss: 2.113553
#
# Test set: Average loss: 2.3407, Accuracy: 139/1000 (13.90%)
#
# ✅ New best model saved for 10x10 (13.90%)
# Train Epoch: 4 [0/100 (0%)]	Loss: 1.946810
#
# Test set: Average loss: 2.3292, Accuracy: 158/1000 (15.80%)
#
# ✅ New best model saved for 10x10 (15.80%)
# Train Epoch: 5 [0/100 (0%)]	Loss: 1.732701
#
# Test set: Average loss: 2.2869, Accuracy: 190/1000 (19.00%)
#
# ✅ New best model saved for 10x10 (19.00%)
# Train Epoch: 6 [0/100 (0%)]	Loss: 1.483908
#
# Test set: Average loss: 2.1998, Accuracy: 213/1000 (21.30%)
#
# ✅ New best model saved for 10x10 (21.30%)
# Train Epoch: 7 [0/100 (0%)]	Loss: 1.274968
#
# Test set: Average loss: 2.0934, Accuracy: 251/1000 (25.10%)
#
# ✅ New best model saved for 10x10 (25.10%)
# Train Epoch: 8 [0/100 (0%)]	Loss: 1.048482
#
# Test set: Average loss: 2.0197, Accuracy: 287/1000 (28.70%)
#
# ✅ New best model saved for 10x10 (28.70%)
# Train Epoch: 9 [0/100 (0%)]	Loss: 0.839178
#
# Test set: Average loss: 1.9689, Accuracy: 307/1000 (30.70%)
#
# ✅ New best model saved for 10x10 (30.70%)
# Train Epoch: 10 [0/100 (0%)]	Loss: 0.734456
#
# Test set: Average loss: 1.9145, Accuracy: 352/1000 (35.20%)
#
# ✅ New best model saved for 10x10 (35.20%)
# Train Epoch: 11 [0/100 (0%)]	Loss: 0.600231
#
# Test set: Average loss: 1.8632, Accuracy: 373/1000 (37.30%)
#
# ✅ New best model saved for 10x10 (37.30%)
# Train Epoch: 12 [0/100 (0%)]	Loss: 0.436098
#
# Test set: Average loss: 1.8234, Accuracy: 404/1000 (40.40%)
#
# ✅ New best model saved for 10x10 (40.40%)
# Train Epoch: 13 [0/100 (0%)]	Loss: 0.332081
#
# Test set: Average loss: 1.7920, Accuracy: 429/1000 (42.90%)
#
# ✅ New best model saved for 10x10 (42.90%)
# Train Epoch: 14 [0/100 (0%)]	Loss: 0.256441
#
# Test set: Average loss: 1.7719, Accuracy: 440/1000 (44.00%)
#
# ✅ New best model saved for 10x10 (44.00%)
# Train Epoch: 15 [0/100 (0%)]	Loss: 0.203829
#
# Test set: Average loss: 1.7536, Accuracy: 456/1000 (45.60%)
#
# ✅ New best model saved for 10x10 (45.60%)
# Train Epoch: 16 [0/100 (0%)]	Loss: 0.134371
#
# Test set: Average loss: 1.7442, Accuracy: 464/1000 (46.40%)
#
# ✅ New best model saved for 10x10 (46.40%)
# Train Epoch: 17 [0/100 (0%)]	Loss: 0.094663
#
# Test set: Average loss: 1.7443, Accuracy: 462/1000 (46.20%)
#
# Train Epoch: 18 [0/100 (0%)]	Loss: 0.088520
#
# Test set: Average loss: 1.7531, Accuracy: 467/1000 (46.70%)
#
# ✅ New best model saved for 10x10 (46.70%)
# Train Epoch: 19 [0/100 (0%)]	Loss: 0.054980
#
# Test set: Average loss: 1.7664, Accuracy: 463/1000 (46.30%)
#
# Train Epoch: 20 [0/100 (0%)]	Loss: 0.043225
#
# Test set: Average loss: 1.7738, Accuracy: 466/1000 (46.60%)
#
# Train Epoch: 21 [0/100 (0%)]	Loss: 0.035528
#
# Test set: Average loss: 1.7732, Accuracy: 474/1000 (47.40%)
#
# ✅ New best model saved for 10x10 (47.40%)
# Train Epoch: 22 [0/100 (0%)]	Loss: 0.024037
#
# Test set: Average loss: 1.7723, Accuracy: 482/1000 (48.20%)
#
# ✅ New best model saved for 10x10 (48.20%)
# Train Epoch: 23 [0/100 (0%)]	Loss: 0.021664
#
# Test set: Average loss: 1.7675, Accuracy: 486/1000 (48.60%)
#
# ✅ New best model saved for 10x10 (48.60%)
# Train Epoch: 24 [0/100 (0%)]	Loss: 0.017972
#
# Test set: Average loss: 1.7607, Accuracy: 490/1000 (49.00%)
#
# ✅ New best model saved for 10x10 (49.00%)
# Train Epoch: 25 [0/100 (0%)]	Loss: 0.020422
#
# Test set: Average loss: 1.7528, Accuracy: 493/1000 (49.30%)
#
# ✅ New best model saved for 10x10 (49.30%)
# Train Epoch: 26 [0/100 (0%)]	Loss: 0.012849
#
# Test set: Average loss: 1.7460, Accuracy: 493/1000 (49.30%)
#
# Train Epoch: 27 [0/100 (0%)]	Loss: 0.015161
#
# Test set: Average loss: 1.7420, Accuracy: 496/1000 (49.60%)
#
# ✅ New best model saved for 10x10 (49.60%)
# Train Epoch: 28 [0/100 (0%)]	Loss: 0.009513
#
# Test set: Average loss: 1.7414, Accuracy: 496/1000 (49.60%)
#
# Train Epoch: 29 [0/100 (0%)]	Loss: 0.009127
#
# Test set: Average loss: 1.7400, Accuracy: 502/1000 (50.20%)
#
# ✅ New best model saved for 10x10 (50.20%)
# Train Epoch: 30 [0/100 (0%)]	Loss: 0.005755
#
# Test set: Average loss: 1.7388, Accuracy: 510/1000 (51.00%)
#
# ✅ New best model saved for 10x10 (51.00%)
# Train Epoch: 31 [0/100 (0%)]	Loss: 0.007756
#
# Test set: Average loss: 1.7385, Accuracy: 513/1000 (51.30%)
#
# ✅ New best model saved for 10x10 (51.30%)
# Train Epoch: 32 [0/100 (0%)]	Loss: 0.006831
#
# Test set: Average loss: 1.7412, Accuracy: 518/1000 (51.80%)
#
# ✅ New best model saved for 10x10 (51.80%)
# Train Epoch: 33 [0/100 (0%)]	Loss: 0.007832
#
# Test set: Average loss: 1.7410, Accuracy: 521/1000 (52.10%)
#
# ✅ New best model saved for 10x10 (52.10%)
# Train Epoch: 34 [0/100 (0%)]	Loss: 0.005214
#
# Test set: Average loss: 1.7427, Accuracy: 520/1000 (52.00%)
#
# Train Epoch: 35 [0/100 (0%)]	Loss: 0.005529
#
# Test set: Average loss: 1.7428, Accuracy: 524/1000 (52.40%)
#
# ✅ New best model saved for 10x10 (52.40%)
# Train Epoch: 36 [0/100 (0%)]	Loss: 0.003833
#
# Test set: Average loss: 1.7447, Accuracy: 526/1000 (52.60%)
#
# ✅ New best model saved for 10x10 (52.60%)
# Train Epoch: 37 [0/100 (0%)]	Loss: 0.005213
#
# Test set: Average loss: 1.7465, Accuracy: 526/1000 (52.60%)
#
# Train Epoch: 38 [0/100 (0%)]	Loss: 0.002732
#
# Test set: Average loss: 1.7480, Accuracy: 528/1000 (52.80%)
#
# ✅ New best model saved for 10x10 (52.80%)
# Train Epoch: 39 [0/100 (0%)]	Loss: 0.003231
#
# Test set: Average loss: 1.7507, Accuracy: 529/1000 (52.90%)
#
# ✅ New best model saved for 10x10 (52.90%)
# Train Epoch: 40 [0/100 (0%)]	Loss: 0.003728
#
# Test set: Average loss: 1.7514, Accuracy: 530/1000 (53.00%)
#
# ✅ New best model saved for 10x10 (53.00%)
# Train Epoch: 41 [0/100 (0%)]	Loss: 0.002491
#
# Test set: Average loss: 1.7521, Accuracy: 533/1000 (53.30%)
#
# ✅ New best model saved for 10x10 (53.30%)
# Train Epoch: 42 [0/100 (0%)]	Loss: 0.002366
#
# Test set: Average loss: 1.7516, Accuracy: 533/1000 (53.30%)
#
# Train Epoch: 43 [0/100 (0%)]	Loss: 0.002090
#
# Test set: Average loss: 1.7514, Accuracy: 535/1000 (53.50%)
#
# ✅ New best model saved for 10x10 (53.50%)
# Train Epoch: 44 [0/100 (0%)]	Loss: 0.002714
#
# Test set: Average loss: 1.7499, Accuracy: 537/1000 (53.70%)
#
# ✅ New best model saved for 10x10 (53.70%)
# Train Epoch: 45 [0/100 (0%)]	Loss: 0.001899
#
# Test set: Average loss: 1.7507, Accuracy: 536/1000 (53.60%)
#
# Train Epoch: 46 [0/100 (0%)]	Loss: 0.001773
#
# Test set: Average loss: 1.7519, Accuracy: 536/1000 (53.60%)
#
# Train Epoch: 47 [0/100 (0%)]	Loss: 0.002271
#
# Test set: Average loss: 1.7507, Accuracy: 538/1000 (53.80%)
#
# ✅ New best model saved for 10x10 (53.80%)
# Train Epoch: 48 [0/100 (0%)]	Loss: 0.001949
#
# Test set: Average loss: 1.7488, Accuracy: 537/1000 (53.70%)
#
# Train Epoch: 49 [0/100 (0%)]	Loss: 0.001810
#
# Test set: Average loss: 1.7458, Accuracy: 537/1000 (53.70%)
#
# Train Epoch: 50 [0/100 (0%)]	Loss: 0.002352
#
# Test set: Average loss: 1.7469, Accuracy: 537/1000 (53.70%)
#
#
# 🎯 Final best accuracy for 10x10: 53.80%
#
# =======================================================
# --- Training ResNet-18 on 10x200 (10 classes) ---
# =======================================================
# Train Epoch: 1 [0/2000 (0%)]	Loss: 2.619722
#
# Test set: Average loss: 1.8124, Accuracy: 399/1000 (39.90%)
#
# ✅ New best model saved for 10x200 (39.90%)
# Train Epoch: 2 [0/2000 (0%)]	Loss: 1.217391
#
# Test set: Average loss: 1.0224, Accuracy: 684/1000 (68.40%)
#
# ✅ New best model saved for 10x200 (68.40%)
# Train Epoch: 3 [0/2000 (0%)]	Loss: 0.625057
#
# Test set: Average loss: 1.2431, Accuracy: 662/1000 (66.20%)
#
# Train Epoch: 4 [0/2000 (0%)]	Loss: 0.487899
#
# Test set: Average loss: 0.6142, Accuracy: 812/1000 (81.20%)
#
# ✅ New best model saved for 10x200 (81.20%)
# Train Epoch: 5 [0/2000 (0%)]	Loss: 0.282617
#
# Test set: Average loss: 0.6455, Accuracy: 808/1000 (80.80%)
#
# Train Epoch: 6 [0/2000 (0%)]	Loss: 0.187625
#
# Test set: Average loss: 0.6511, Accuracy: 803/1000 (80.30%)
#
# Train Epoch: 7 [0/2000 (0%)]	Loss: 0.164068
#
# Test set: Average loss: 0.6477, Accuracy: 799/1000 (79.90%)
#
# Train Epoch: 8 [0/2000 (0%)]	Loss: 0.117938
#
# Test set: Average loss: 0.6319, Accuracy: 835/1000 (83.50%)
#
# ✅ New best model saved for 10x200 (83.50%)
# Train Epoch: 9 [0/2000 (0%)]	Loss: 0.108790
#
# Test set: Average loss: 0.6094, Accuracy: 836/1000 (83.60%)
#
# ✅ New best model saved for 10x200 (83.60%)
# Train Epoch: 10 [0/2000 (0%)]	Loss: 0.054132
#
# Test set: Average loss: 0.5859, Accuracy: 837/1000 (83.70%)
#
# ✅ New best model saved for 10x200 (83.70%)
# Train Epoch: 11 [0/2000 (0%)]	Loss: 0.047724
#
# Test set: Average loss: 0.6445, Accuracy: 834/1000 (83.40%)
#
# Train Epoch: 12 [0/2000 (0%)]	Loss: 0.056866
#
# Test set: Average loss: 0.6085, Accuracy: 840/1000 (84.00%)
#
# ✅ New best model saved for 10x200 (84.00%)
# Train Epoch: 13 [0/2000 (0%)]	Loss: 0.026348
#
# Test set: Average loss: 0.5454, Accuracy: 845/1000 (84.50%)
#
# ✅ New best model saved for 10x200 (84.50%)
# Train Epoch: 14 [0/2000 (0%)]	Loss: 0.010632
#
# Test set: Average loss: 0.6219, Accuracy: 849/1000 (84.90%)
#
# ✅ New best model saved for 10x200 (84.90%)
# Train Epoch: 15 [0/2000 (0%)]	Loss: 0.037677
#
# Test set: Average loss: 0.5851, Accuracy: 849/1000 (84.90%)
#
# Train Epoch: 16 [0/2000 (0%)]	Loss: 0.018302
#
# Test set: Average loss: 0.6154, Accuracy: 850/1000 (85.00%)
#
# ✅ New best model saved for 10x200 (85.00%)
# Train Epoch: 17 [0/2000 (0%)]	Loss: 0.025883
#
# Test set: Average loss: 0.5123, Accuracy: 871/1000 (87.10%)
#
# ✅ New best model saved for 10x200 (87.10%)
# Train Epoch: 18 [0/2000 (0%)]	Loss: 0.013558
#
# Test set: Average loss: 0.5606, Accuracy: 854/1000 (85.40%)
#
# Train Epoch: 19 [0/2000 (0%)]	Loss: 0.022801
#
# Test set: Average loss: 0.6013, Accuracy: 860/1000 (86.00%)
#
# Train Epoch: 20 [0/2000 (0%)]	Loss: 0.006337
#
# Test set: Average loss: 0.5567, Accuracy: 867/1000 (86.70%)
#
# Train Epoch: 21 [0/2000 (0%)]	Loss: 0.011841
#
# Test set: Average loss: 0.5496, Accuracy: 863/1000 (86.30%)
#
# Train Epoch: 22 [0/2000 (0%)]	Loss: 0.017194
#
# Test set: Average loss: 0.5743, Accuracy: 856/1000 (85.60%)
#
# Train Epoch: 23 [0/2000 (0%)]	Loss: 0.007999
#
# Test set: Average loss: 0.5604, Accuracy: 859/1000 (85.90%)
#
# Train Epoch: 24 [0/2000 (0%)]	Loss: 0.004539
#
# Test set: Average loss: 0.5952, Accuracy: 864/1000 (86.40%)
#
# Train Epoch: 25 [0/2000 (0%)]	Loss: 0.019848
#
# Test set: Average loss: 0.5934, Accuracy: 872/1000 (87.20%)
#
# ✅ New best model saved for 10x200 (87.20%)
# Train Epoch: 26 [0/2000 (0%)]	Loss: 0.001850
#
# Test set: Average loss: 0.6319, Accuracy: 859/1000 (85.90%)
#
# Train Epoch: 27 [0/2000 (0%)]	Loss: 0.007297
#
# Test set: Average loss: 0.6054, Accuracy: 855/1000 (85.50%)
#
# Train Epoch: 28 [0/2000 (0%)]	Loss: 0.003448
#
# Test set: Average loss: 0.5623, Accuracy: 871/1000 (87.10%)
#
# Train Epoch: 29 [0/2000 (0%)]	Loss: 0.002138
#
# Test set: Average loss: 0.6205, Accuracy: 859/1000 (85.90%)
#
# Train Epoch: 30 [0/2000 (0%)]	Loss: 0.018891
#
# Test set: Average loss: 0.5630, Accuracy: 862/1000 (86.20%)
#
# Train Epoch: 31 [0/2000 (0%)]	Loss: 0.004214
#
# Test set: Average loss: 0.5794, Accuracy: 858/1000 (85.80%)
#
# Train Epoch: 32 [0/2000 (0%)]	Loss: 0.003631
#
# Test set: Average loss: 0.5118, Accuracy: 874/1000 (87.40%)
#
# ✅ New best model saved for 10x200 (87.40%)
# Train Epoch: 33 [0/2000 (0%)]	Loss: 0.000837
#
# Test set: Average loss: 0.5389, Accuracy: 870/1000 (87.00%)
#
# Train Epoch: 34 [0/2000 (0%)]	Loss: 0.003411
#
# Test set: Average loss: 0.5422, Accuracy: 879/1000 (87.90%)
#
# ✅ New best model saved for 10x200 (87.90%)
# Train Epoch: 35 [0/2000 (0%)]	Loss: 0.004970
#
# Test set: Average loss: 0.5299, Accuracy: 874/1000 (87.40%)
#
# Train Epoch: 36 [0/2000 (0%)]	Loss: 0.003104
#
# Test set: Average loss: 0.5213, Accuracy: 882/1000 (88.20%)
#
# ✅ New best model saved for 10x200 (88.20%)
# Train Epoch: 37 [0/2000 (0%)]	Loss: 0.021830
#
# Test set: Average loss: 0.5047, Accuracy: 879/1000 (87.90%)
#
# Train Epoch: 38 [0/2000 (0%)]	Loss: 0.001178
#
# Test set: Average loss: 0.5034, Accuracy: 877/1000 (87.70%)
#
# Train Epoch: 39 [0/2000 (0%)]	Loss: 0.000841
#
# Test set: Average loss: 0.5059, Accuracy: 878/1000 (87.80%)
#
# Train Epoch: 40 [0/2000 (0%)]	Loss: 0.001479
#
# Test set: Average loss: 0.5167, Accuracy: 877/1000 (87.70%)
#
# Train Epoch: 41 [0/2000 (0%)]	Loss: 0.001174
#
# Test set: Average loss: 0.5051, Accuracy: 881/1000 (88.10%)
#
# Train Epoch: 42 [0/2000 (0%)]	Loss: 0.001303
#
# Test set: Average loss: 0.4951, Accuracy: 882/1000 (88.20%)
#
# Train Epoch: 43 [0/2000 (0%)]	Loss: 0.000598
#
# Test set: Average loss: 0.5462, Accuracy: 873/1000 (87.30%)
#
# Train Epoch: 44 [0/2000 (0%)]	Loss: 0.004159
#
# Test set: Average loss: 0.5203, Accuracy: 878/1000 (87.80%)
#
# Train Epoch: 45 [0/2000 (0%)]	Loss: 0.000852
#
# Test set: Average loss: 0.5121, Accuracy: 881/1000 (88.10%)
#
# Train Epoch: 46 [0/2000 (0%)]	Loss: 0.000842
#
# Test set: Average loss: 0.5143, Accuracy: 872/1000 (87.20%)
#
# Train Epoch: 47 [0/2000 (0%)]	Loss: 0.003329
#
# Test set: Average loss: 0.5848, Accuracy: 873/1000 (87.30%)
#
# Train Epoch: 48 [0/2000 (0%)]	Loss: 0.001292
#
# Test set: Average loss: 0.5710, Accuracy: 867/1000 (86.70%)
#
# Train Epoch: 49 [0/2000 (0%)]	Loss: 0.000605
#
# Test set: Average loss: 0.5766, Accuracy: 865/1000 (86.50%)
#
# Train Epoch: 50 [0/2000 (0%)]	Loss: 0.001033
#
# Test set: Average loss: 0.5311, Accuracy: 868/1000 (86.80%)
#
#
# 🎯 Final best accuracy for 10x200: 88.20%
#
# =======================================================
# --- Training ResNet-18 on 100x10 (100 classes) ---
# =======================================================
# Train Epoch: 1 [0/1000 (0%)]	Loss: 4.960540
#
# Test set: Average loss: 4.6406, Accuracy: 141/10000 (1.41%)
#
# ✅ New best model saved for 100x10 (1.41%)
# Train Epoch: 2 [0/1000 (0%)]	Loss: 4.464635
#
# Test set: Average loss: 4.5383, Accuracy: 364/10000 (3.64%)
#
# ✅ New best model saved for 100x10 (3.64%)
# Train Epoch: 3 [0/1000 (0%)]	Loss: 4.176830
#
# Test set: Average loss: 4.2614, Accuracy: 740/10000 (7.40%)
#
# ✅ New best model saved for 100x10 (7.40%)
# Train Epoch: 4 [0/1000 (0%)]	Loss: 3.482193
#
# Test set: Average loss: 3.9887, Accuracy: 1091/10000 (10.91%)
#
# ✅ New best model saved for 100x10 (10.91%)
# Train Epoch: 5 [0/1000 (0%)]	Loss: 2.971284
#
# Test set: Average loss: 3.7790, Accuracy: 1445/10000 (14.45%)
#
# ✅ New best model saved for 100x10 (14.45%)
# Train Epoch: 6 [0/1000 (0%)]	Loss: 2.457876
#
# Test set: Average loss: 3.5954, Accuracy: 1726/10000 (17.26%)
#
# ✅ New best model saved for 100x10 (17.26%)
# Train Epoch: 7 [0/1000 (0%)]	Loss: 1.875455
#
# Test set: Average loss: 3.5298, Accuracy: 1907/10000 (19.07%)
#
# ✅ New best model saved for 100x10 (19.07%)
# Train Epoch: 8 [0/1000 (0%)]	Loss: 1.557575
#
# Test set: Average loss: 3.4635, Accuracy: 1996/10000 (19.96%)
#
# ✅ New best model saved for 100x10 (19.96%)
# Train Epoch: 9 [0/1000 (0%)]	Loss: 1.136758
#
# Test set: Average loss: 3.4458, Accuracy: 2007/10000 (20.07%)
#
# ✅ New best model saved for 100x10 (20.07%)
# Train Epoch: 10 [0/1000 (0%)]	Loss: 1.031217
#
# Test set: Average loss: 3.4013, Accuracy: 2107/10000 (21.07%)
#
# ✅ New best model saved for 100x10 (21.07%)
# Train Epoch: 11 [0/1000 (0%)]	Loss: 0.828296
#
# Test set: Average loss: 3.4137, Accuracy: 2156/10000 (21.56%)
#
# ✅ New best model saved for 100x10 (21.56%)
# Train Epoch: 12 [0/1000 (0%)]	Loss: 0.597626
#
# Test set: Average loss: 3.4163, Accuracy: 2231/10000 (22.31%)
#
# ✅ New best model saved for 100x10 (22.31%)
# Train Epoch: 13 [0/1000 (0%)]	Loss: 0.446494
#
# Test set: Average loss: 3.4002, Accuracy: 2294/10000 (22.94%)
#
# ✅ New best model saved for 100x10 (22.94%)
# Train Epoch: 14 [0/1000 (0%)]	Loss: 0.255202
#
# Test set: Average loss: 3.4106, Accuracy: 2291/10000 (22.91%)
#
# Train Epoch: 15 [0/1000 (0%)]	Loss: 0.223391
#
# Test set: Average loss: 3.4016, Accuracy: 2292/10000 (22.92%)
#
# Train Epoch: 16 [0/1000 (0%)]	Loss: 0.174881
#
# Test set: Average loss: 3.4033, Accuracy: 2328/10000 (23.28%)
#
# ✅ New best model saved for 100x10 (23.28%)
# Train Epoch: 17 [0/1000 (0%)]	Loss: 0.132475
#
# Test set: Average loss: 3.4169, Accuracy: 2335/10000 (23.35%)
#
# ✅ New best model saved for 100x10 (23.35%)
# Train Epoch: 18 [0/1000 (0%)]	Loss: 0.114391
#
# Test set: Average loss: 3.4162, Accuracy: 2345/10000 (23.45%)
#
# ✅ New best model saved for 100x10 (23.45%)
# Train Epoch: 19 [0/1000 (0%)]	Loss: 0.085690
#
# Test set: Average loss: 3.4246, Accuracy: 2374/10000 (23.74%)
#
# ✅ New best model saved for 100x10 (23.74%)
# Train Epoch: 20 [0/1000 (0%)]	Loss: 0.075797
#
# Test set: Average loss: 3.4331, Accuracy: 2390/10000 (23.90%)
#
# ✅ New best model saved for 100x10 (23.90%)
# Train Epoch: 21 [0/1000 (0%)]	Loss: 0.085884
#
# Test set: Average loss: 3.4389, Accuracy: 2341/10000 (23.41%)
#
# Train Epoch: 22 [0/1000 (0%)]	Loss: 0.057661
#
# Test set: Average loss: 3.4409, Accuracy: 2360/10000 (23.60%)
#
# Train Epoch: 23 [0/1000 (0%)]	Loss: 0.067849
#
# Test set: Average loss: 3.4358, Accuracy: 2397/10000 (23.97%)
#
# ✅ New best model saved for 100x10 (23.97%)
# Train Epoch: 24 [0/1000 (0%)]	Loss: 0.055383
#
# Test set: Average loss: 3.4279, Accuracy: 2424/10000 (24.24%)
#
# ✅ New best model saved for 100x10 (24.24%)
# Train Epoch: 25 [0/1000 (0%)]	Loss: 0.051620
#
# Test set: Average loss: 3.4390, Accuracy: 2409/10000 (24.09%)
#
# Train Epoch: 26 [0/1000 (0%)]	Loss: 0.042415
#
# Test set: Average loss: 3.4480, Accuracy: 2409/10000 (24.09%)
#
# Train Epoch: 27 [0/1000 (0%)]	Loss: 0.039336
#
# Test set: Average loss: 3.4424, Accuracy: 2450/10000 (24.50%)
#
# ✅ New best model saved for 100x10 (24.50%)
# Train Epoch: 28 [0/1000 (0%)]	Loss: 0.038799
#
# Test set: Average loss: 3.4449, Accuracy: 2425/10000 (24.25%)
#
# Train Epoch: 29 [0/1000 (0%)]	Loss: 0.035648
#
# Test set: Average loss: 3.4479, Accuracy: 2432/10000 (24.32%)
#
# Train Epoch: 30 [0/1000 (0%)]	Loss: 0.029208
#
# Test set: Average loss: 3.4444, Accuracy: 2439/10000 (24.39%)
#
# Train Epoch: 31 [0/1000 (0%)]	Loss: 0.031333
#
# Test set: Average loss: 3.4370, Accuracy: 2451/10000 (24.51%)
#
# ✅ New best model saved for 100x10 (24.51%)
# Train Epoch: 32 [0/1000 (0%)]	Loss: 0.030691
#
# Test set: Average loss: 3.4568, Accuracy: 2442/10000 (24.42%)
#
# Train Epoch: 33 [0/1000 (0%)]	Loss: 0.024444
#
# Test set: Average loss: 3.4599, Accuracy: 2443/10000 (24.43%)
#
# Train Epoch: 34 [0/1000 (0%)]	Loss: 0.029125
#
# Test set: Average loss: 3.4618, Accuracy: 2453/10000 (24.53%)
#
# ✅ New best model saved for 100x10 (24.53%)
# Train Epoch: 35 [0/1000 (0%)]	Loss: 0.023811
#
# Test set: Average loss: 3.4667, Accuracy: 2471/10000 (24.71%)
#
# ✅ New best model saved for 100x10 (24.71%)
# Train Epoch: 36 [0/1000 (0%)]	Loss: 0.024400
#
# Test set: Average loss: 3.4700, Accuracy: 2465/10000 (24.65%)
#
# Train Epoch: 37 [0/1000 (0%)]	Loss: 0.018815
#
# Test set: Average loss: 3.4695, Accuracy: 2451/10000 (24.51%)
#
# Train Epoch: 38 [0/1000 (0%)]	Loss: 0.023896
#
# Test set: Average loss: 3.4742, Accuracy: 2430/10000 (24.30%)
#
# Train Epoch: 39 [0/1000 (0%)]	Loss: 0.019740
#
# Test set: Average loss: 3.4691, Accuracy: 2449/10000 (24.49%)
#
# Train Epoch: 40 [0/1000 (0%)]	Loss: 0.019004
#
# Test set: Average loss: 3.4733, Accuracy: 2453/10000 (24.53%)
#
# Train Epoch: 41 [0/1000 (0%)]	Loss: 0.023629
#
# Test set: Average loss: 3.4715, Accuracy: 2454/10000 (24.54%)
#
# Train Epoch: 42 [0/1000 (0%)]	Loss: 0.018806
#
# Test set: Average loss: 3.4780, Accuracy: 2459/10000 (24.59%)
#
# Train Epoch: 43 [0/1000 (0%)]	Loss: 0.020475
#
# Test set: Average loss: 3.4792, Accuracy: 2468/10000 (24.68%)
#
# Train Epoch: 44 [0/1000 (0%)]	Loss: 0.019728
#
# Test set: Average loss: 3.4777, Accuracy: 2483/10000 (24.83%)
#
# ✅ New best model saved for 100x10 (24.83%)
# Train Epoch: 45 [0/1000 (0%)]	Loss: 0.019916
#
# Test set: Average loss: 3.4802, Accuracy: 2472/10000 (24.72%)
#
# Train Epoch: 46 [0/1000 (0%)]	Loss: 0.014495
#
# Test set: Average loss: 3.4799, Accuracy: 2469/10000 (24.69%)
#
# Train Epoch: 47 [0/1000 (0%)]	Loss: 0.017552
#
# Test set: Average loss: 3.4818, Accuracy: 2477/10000 (24.77%)
#
# Train Epoch: 48 [0/1000 (0%)]	Loss: 0.017999
#
# Test set: Average loss: 3.4852, Accuracy: 2493/10000 (24.93%)
#
# ✅ New best model saved for 100x10 (24.93%)
# Train Epoch: 49 [0/1000 (0%)]	Loss: 0.015605
#
# Test set: Average loss: 3.4866, Accuracy: 2479/10000 (24.79%)
#
# Train Epoch: 50 [0/1000 (0%)]	Loss: 0.018089
#
# Test set: Average loss: 3.4924, Accuracy: 2484/10000 (24.84%)
#
#
# 🎯 Final best accuracy for 100x10: 24.93%
#
# =======================================================
# --- Training ResNet-18 on 100x200 (100 classes) ---
# =======================================================
# Train Epoch: 1 [0/20000 (0%)]	Loss: 4.970771
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 2.787836
#
# Test set: Average loss: 2.2727, Accuracy: 3980/10000 (39.80%)
#
# ✅ New best model saved for 100x200 (39.80%)
# Train Epoch: 2 [0/20000 (0%)]	Loss: 1.879348
# Train Epoch: 2 [12800/20000 (64%)]	Loss: 1.612508
#
# Test set: Average loss: 1.6888, Accuracy: 5298/10000 (52.98%)
#
# ✅ New best model saved for 100x200 (52.98%)
# Train Epoch: 3 [0/20000 (0%)]	Loss: 1.415192
# Train Epoch: 3 [12800/20000 (64%)]	Loss: 1.039808
#
# Test set: Average loss: 1.5575, Accuracy: 5619/10000 (56.19%)
#
# ✅ New best model saved for 100x200 (56.19%)
# Train Epoch: 4 [0/20000 (0%)]	Loss: 1.030167
# Train Epoch: 4 [12800/20000 (64%)]	Loss: 0.986696
#
# Test set: Average loss: 1.3948, Accuracy: 6112/10000 (61.12%)
#
# ✅ New best model saved for 100x200 (61.12%)
# Train Epoch: 5 [0/20000 (0%)]	Loss: 0.783182
# Train Epoch: 5 [12800/20000 (64%)]	Loss: 0.864170
#
# Test set: Average loss: 1.3267, Accuracy: 6293/10000 (62.93%)
#
# ✅ New best model saved for 100x200 (62.93%)
# Train Epoch: 6 [0/20000 (0%)]	Loss: 0.620217
# Train Epoch: 6 [12800/20000 (64%)]	Loss: 0.852659
#
# Test set: Average loss: 1.3005, Accuracy: 6436/10000 (64.36%)
#
# ✅ New best model saved for 100x200 (64.36%)
# Train Epoch: 7 [0/20000 (0%)]	Loss: 0.600465
# Train Epoch: 7 [12800/20000 (64%)]	Loss: 0.556246
#
# Test set: Average loss: 1.2553, Accuracy: 6536/10000 (65.36%)
#
# ✅ New best model saved for 100x200 (65.36%)
# Train Epoch: 8 [0/20000 (0%)]	Loss: 0.389525
# Train Epoch: 8 [12800/20000 (64%)]	Loss: 0.413745
#
# Test set: Average loss: 1.3412, Accuracy: 6534/10000 (65.34%)
#
# Train Epoch: 9 [0/20000 (0%)]	Loss: 0.375478
# Train Epoch: 9 [12800/20000 (64%)]	Loss: 0.520597
#
# Test set: Average loss: 1.3198, Accuracy: 6532/10000 (65.32%)
#
# Train Epoch: 10 [0/20000 (0%)]	Loss: 0.347867
# Train Epoch: 10 [12800/20000 (64%)]	Loss: 0.319396
#
# Test set: Average loss: 1.2624, Accuracy: 6733/10000 (67.33%)
#
# ✅ New best model saved for 100x200 (67.33%)
# Train Epoch: 11 [0/20000 (0%)]	Loss: 0.258893
# Train Epoch: 11 [12800/20000 (64%)]	Loss: 0.277253
#
# Test set: Average loss: 1.2820, Accuracy: 6745/10000 (67.45%)
#
# ✅ New best model saved for 100x200 (67.45%)
# Train Epoch: 12 [0/20000 (0%)]	Loss: 0.186329
# Train Epoch: 12 [12800/20000 (64%)]	Loss: 0.227318
#
# Test set: Average loss: 1.2727, Accuracy: 6788/10000 (67.88%)
#
# ✅ New best model saved for 100x200 (67.88%)
# Train Epoch: 13 [0/20000 (0%)]	Loss: 0.202002
# Train Epoch: 13 [12800/20000 (64%)]	Loss: 0.141280
#
# Test set: Average loss: 1.3026, Accuracy: 6801/10000 (68.01%)
#
# ✅ New best model saved for 100x200 (68.01%)
# Train Epoch: 14 [0/20000 (0%)]	Loss: 0.109354
# Train Epoch: 14 [12800/20000 (64%)]	Loss: 0.196659
#
# Test set: Average loss: 1.3148, Accuracy: 6790/10000 (67.90%)
#
# Train Epoch: 15 [0/20000 (0%)]	Loss: 0.130581
# Train Epoch: 15 [12800/20000 (64%)]	Loss: 0.217817
#
# Test set: Average loss: 1.3345, Accuracy: 6772/10000 (67.72%)
#
# Train Epoch: 16 [0/20000 (0%)]	Loss: 0.060320
# Train Epoch: 16 [12800/20000 (64%)]	Loss: 0.096064
#
# Test set: Average loss: 1.2651, Accuracy: 6916/10000 (69.16%)
#
# ✅ New best model saved for 100x200 (69.16%)
# Train Epoch: 17 [0/20000 (0%)]	Loss: 0.080601
# Train Epoch: 17 [12800/20000 (64%)]	Loss: 0.130529
#
# Test set: Average loss: 1.2800, Accuracy: 6924/10000 (69.24%)
#
# ✅ New best model saved for 100x200 (69.24%)
# Train Epoch: 18 [0/20000 (0%)]	Loss: 0.065994
# Train Epoch: 18 [12800/20000 (64%)]	Loss: 0.111522
#
# Test set: Average loss: 1.2887, Accuracy: 6919/10000 (69.19%)
#
# Train Epoch: 19 [0/20000 (0%)]	Loss: 0.062982
# Train Epoch: 19 [12800/20000 (64%)]	Loss: 0.088465
#
# Test set: Average loss: 1.2885, Accuracy: 6971/10000 (69.71%)
#
# ✅ New best model saved for 100x200 (69.71%)
# Train Epoch: 20 [0/20000 (0%)]	Loss: 0.071267
# Train Epoch: 20 [12800/20000 (64%)]	Loss: 0.083187
#
# Test set: Average loss: 1.2826, Accuracy: 7021/10000 (70.21%)
#
# ✅ New best model saved for 100x200 (70.21%)
# Train Epoch: 21 [0/20000 (0%)]	Loss: 0.069162
# Train Epoch: 21 [12800/20000 (64%)]	Loss: 0.073612
#
# Test set: Average loss: 1.2897, Accuracy: 6952/10000 (69.52%)
#
# Train Epoch: 22 [0/20000 (0%)]	Loss: 0.036351
# Train Epoch: 22 [12800/20000 (64%)]	Loss: 0.114688
#
# Test set: Average loss: 1.3284, Accuracy: 6932/10000 (69.32%)
#
# Train Epoch: 23 [0/20000 (0%)]	Loss: 0.105057
# Train Epoch: 23 [12800/20000 (64%)]	Loss: 0.080822
#
# Test set: Average loss: 1.2677, Accuracy: 7072/10000 (70.72%)
#
# ✅ New best model saved for 100x200 (70.72%)
# Train Epoch: 24 [0/20000 (0%)]	Loss: 0.053014
# Train Epoch: 24 [12800/20000 (64%)]	Loss: 0.048862
#
# Test set: Average loss: 1.2624, Accuracy: 7033/10000 (70.33%)
#
# Train Epoch: 25 [0/20000 (0%)]	Loss: 0.022024
# Train Epoch: 25 [12800/20000 (64%)]	Loss: 0.034946
#
# Test set: Average loss: 1.2410, Accuracy: 7119/10000 (71.19%)
#
# ✅ New best model saved for 100x200 (71.19%)
# Train Epoch: 26 [0/20000 (0%)]	Loss: 0.045636
# Train Epoch: 26 [12800/20000 (64%)]	Loss: 0.039914
#
# Test set: Average loss: 1.2638, Accuracy: 7102/10000 (71.02%)
#
# Train Epoch: 27 [0/20000 (0%)]	Loss: 0.036167
# Train Epoch: 27 [12800/20000 (64%)]	Loss: 0.035677
#
# Test set: Average loss: 1.2434, Accuracy: 7150/10000 (71.50%)
#
# ✅ New best model saved for 100x200 (71.50%)
# Train Epoch: 28 [0/20000 (0%)]	Loss: 0.020849
# Train Epoch: 28 [12800/20000 (64%)]	Loss: 0.026680
#
# Test set: Average loss: 1.2401, Accuracy: 7136/10000 (71.36%)
#
# Train Epoch: 29 [0/20000 (0%)]	Loss: 0.025272
# Train Epoch: 29 [12800/20000 (64%)]	Loss: 0.031580
#
# Test set: Average loss: 1.2034, Accuracy: 7195/10000 (71.95%)
#
# ✅ New best model saved for 100x200 (71.95%)
# Train Epoch: 30 [0/20000 (0%)]	Loss: 0.019040
# Train Epoch: 30 [12800/20000 (64%)]	Loss: 0.014677
#
# Test set: Average loss: 1.2102, Accuracy: 7141/10000 (71.41%)
#
# Train Epoch: 31 [0/20000 (0%)]	Loss: 0.026550
# Train Epoch: 31 [12800/20000 (64%)]	Loss: 0.024853
#
# Test set: Average loss: 1.2308, Accuracy: 7072/10000 (70.72%)
#
# Train Epoch: 32 [0/20000 (0%)]	Loss: 0.027728
# Train Epoch: 32 [12800/20000 (64%)]	Loss: 0.018489
#
# Test set: Average loss: 1.1919, Accuracy: 7173/10000 (71.73%)
#
# Train Epoch: 33 [0/20000 (0%)]	Loss: 0.012987
# Train Epoch: 33 [12800/20000 (64%)]	Loss: 0.008990
#
# Test set: Average loss: 1.2118, Accuracy: 7186/10000 (71.86%)
#
# Train Epoch: 34 [0/20000 (0%)]	Loss: 0.039360
# Train Epoch: 34 [12800/20000 (64%)]	Loss: 0.010722
#
# Test set: Average loss: 1.2259, Accuracy: 7077/10000 (70.77%)
#
# Train Epoch: 35 [0/20000 (0%)]	Loss: 0.005022
# Train Epoch: 35 [12800/20000 (64%)]	Loss: 0.025104
#
# Test set: Average loss: 1.1902, Accuracy: 7148/10000 (71.48%)
#
# Train Epoch: 36 [0/20000 (0%)]	Loss: 0.022343
# Train Epoch: 36 [12800/20000 (64%)]	Loss: 0.012831
#
# Test set: Average loss: 1.1749, Accuracy: 7190/10000 (71.90%)
#
# Train Epoch: 37 [0/20000 (0%)]	Loss: 0.022265
# Train Epoch: 37 [12800/20000 (64%)]	Loss: 0.017410
#
# Test set: Average loss: 1.1744, Accuracy: 7219/10000 (72.19%)
#
# ✅ New best model saved for 100x200 (72.19%)
# Train Epoch: 38 [0/20000 (0%)]	Loss: 0.011203
# Train Epoch: 38 [12800/20000 (64%)]	Loss: 0.008185
#
# Test set: Average loss: 1.2171, Accuracy: 7094/10000 (70.94%)
#
# Train Epoch: 39 [0/20000 (0%)]	Loss: 0.010667
# Train Epoch: 39 [12800/20000 (64%)]	Loss: 0.014218
#
# Test set: Average loss: 1.1714, Accuracy: 7189/10000 (71.89%)
#
# Train Epoch: 40 [0/20000 (0%)]	Loss: 0.030303
# Train Epoch: 40 [12800/20000 (64%)]	Loss: 0.012243
#
# Test set: Average loss: 1.1882, Accuracy: 7193/10000 (71.93%)
#
# Train Epoch: 41 [0/20000 (0%)]	Loss: 0.012142
# Train Epoch: 41 [12800/20000 (64%)]	Loss: 0.024229
#
# Test set: Average loss: 1.1746, Accuracy: 7224/10000 (72.24%)
#
# ✅ New best model saved for 100x200 (72.24%)
# Train Epoch: 42 [0/20000 (0%)]	Loss: 0.008588
# Train Epoch: 42 [12800/20000 (64%)]	Loss: 0.008487
#
# Test set: Average loss: 1.1669, Accuracy: 7198/10000 (71.98%)
#
# Train Epoch: 43 [0/20000 (0%)]	Loss: 0.010811
# Train Epoch: 43 [12800/20000 (64%)]	Loss: 0.010443
#
# Test set: Average loss: 1.1447, Accuracy: 7257/10000 (72.57%)
#
# ✅ New best model saved for 100x200 (72.57%)
# Train Epoch: 44 [0/20000 (0%)]	Loss: 0.024958
# Train Epoch: 44 [12800/20000 (64%)]	Loss: 0.011905
#
# Test set: Average loss: 1.1459, Accuracy: 7226/10000 (72.26%)
#
# Train Epoch: 45 [0/20000 (0%)]	Loss: 0.019144
# Train Epoch: 45 [12800/20000 (64%)]	Loss: 0.016506
#
# Test set: Average loss: 1.1594, Accuracy: 7227/10000 (72.27%)
#
# Train Epoch: 46 [0/20000 (0%)]	Loss: 0.007271
# Train Epoch: 46 [12800/20000 (64%)]	Loss: 0.015587
#
# Test set: Average loss: 1.1522, Accuracy: 7183/10000 (71.83%)
#
# Train Epoch: 47 [0/20000 (0%)]	Loss: 0.017912
# Train Epoch: 47 [12800/20000 (64%)]	Loss: 0.026762
#
# Test set: Average loss: 1.1771, Accuracy: 7127/10000 (71.27%)
#
# Train Epoch: 48 [0/20000 (0%)]	Loss: 0.012994
# Train Epoch: 48 [12800/20000 (64%)]	Loss: 0.039242
#
# Test set: Average loss: 1.1557, Accuracy: 7167/10000 (71.67%)
#
# Train Epoch: 49 [0/20000 (0%)]	Loss: 0.011696
# Train Epoch: 49 [12800/20000 (64%)]	Loss: 0.023630
#
# Test set: Average loss: 1.1698, Accuracy: 7188/10000 (71.88%)
#
# Train Epoch: 50 [0/20000 (0%)]	Loss: 0.011567
# Train Epoch: 50 [12800/20000 (64%)]	Loss: 0.015179
#
# Test set: Average loss: 1.1310, Accuracy: 7263/10000 (72.63%)
#
# ✅ New best model saved for 100x200 (72.63%)
#
# 🎯 Final best accuracy for 100x200: 72.63%
#
# ============================================================
# SUMMARY OF RESULTS
# ============================================================
#      10x10 :  53.80%
#     10x200 :  88.20%
#     100x10 :  24.93%
#    100x200 :  72.63%

# %%
loaded_net = ResNet18CustomInput(num_classes, input_channels)
checkpoint = torch.load('cifar100_resnet18_model.pth')
loaded_net.load_state_dict(checkpoint)
loaded_net = loaded_net.to(device)

# %%
image = cv2.imread("/content/apple.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

input_image = transform(image)
input_image = input_image.unsqueeze(0)
input_image = input_image.to(device)

with torch.no_grad():
    outputs = loaded_net(input_image)
_, predicted = torch.max(outputs, 1)

predicted_class = classes[predicted.item()]


confidence = torch.softmax(outputs, dim=1)[0][predicted.item()].item()

plt.imshow(image)
plt.title(f'Predicted Class: {predicted_class}\nConfidence: {confidence:.2f}')
plt.axis('off')
plt.show()

# %%
image = cv2.imread("/content/cat.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

input_image = transform(image)
input_image = input_image.unsqueeze(0)  # Add a batch dimension
input_image = input_image.to(device)# Move the input to the GPU if available

with torch.no_grad():
    outputs = loaded_net(input_image)  # Unsqueeze to add batch dimension
_, predicted = torch.max(outputs, 1)


predicted_class = classes[predicted.item()]

# Get the prediction confidence
confidence = torch.softmax(outputs, dim=1)[0][predicted.item()].item()

# # Show the image and prediction
plt.imshow(image)
plt.title(f'Predicted Class: {predicted_class}\nConfidence: {confidence:.2f}')
plt.axis('off')
plt.show()
